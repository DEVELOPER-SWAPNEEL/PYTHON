# %%
import pandas as pd
import numpy as np

from Logistic_regression import X_train, X_test, y_train

df=pd.read_csv('/Users/hare/Downloads/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'], axis=1)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
df['Survived'].value_counts()
#here 0 says you die and 1 says you lived.
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
input= df.drop('Survived',axis=1)
target = df['Survived']
input
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le_Pclass = LabelEncoder()
le_sex = LabelEncoder()
le_age = LabelEncoder()
le_Fare = LabelEncoder()

input['le_Pclass_n'] = le_Pclass.fit_transform(input['Pclass'])
input['le_sex_n'] = le_sex.fit_transform(input['Sex'])
input['le_age_n'] = le_age.fit_transform(input['Age'])
input['le_Fare_n'] = le_Fare.fit_transform(input['Fare'])
input
# Out:
#      Pclass     Sex   Age     Fare  le_Pclass_n  le_sex_n  le_age_n  le_Fare_n
# 0         3    male  22.0   7.2500            2         1        28         18
# 1         1  female  38.0  71.2833            0         0        51        207
# 2         3  female  26.0   7.9250            2         0        34         41
# 3         1  female  35.0  53.1000            0         0        47        189
# 4         3    male  35.0   8.0500            2         1        47         43
# ..      ...     ...   ...      ...          ...       ...       ...        ...
# 886       2    male  27.0  13.0000            1         1        35         85
# 887       1  female  19.0  30.0000            0         0        24        153
# 888       3  female   NaN  23.4500            2         0        88        131
# 889       1    male  26.0  30.0000            0         1        34        153
# 890       3    male  32.0   7.7500            2         1        42         30
#
# [891 rows x 8 columns]

# %%
input.drop(['Pclass','Sex','Age','Fare'],axis="columns",inplace=True)
input
# Out:
#      le_Pclass_n  le_sex_n  le_age_n  le_Fare_n
# 0              2         1        28         18
# 1              0         0        51        207
# 2              2         0        34         41
# 3              0         0        47        189
# 4              2         1        47         43
# ..           ...       ...       ...        ...
# 886            1         1        35         85
# 887            0         0        24        153
# 888            2         0        88        131
# 889            0         1        34        153
# 890            2         1        42         30
#
# [891 rows x 4 columns]

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(input,target,test_size=0.2)

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.770949720670391

# %%
model.predict([[2,1,28,18]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
